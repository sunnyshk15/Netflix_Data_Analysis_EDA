# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns 
import plotly.express as px

# %%
#importing the dataset
data=pd.read_csv(r'D:\bk\c\Downloads\netflix_titles.csv')

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Getting some basic information about the dataset

# %% [markdown]
# 1.head()

# %%
data.head(5)    # Show top-5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# 2.tail()

# %%
data.tail()   # show top-5 bottom records of dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# 3.shape

# %%
data.shape                     # show the no. of row and columns
# Out:
# (8807, 12)

# %%
data.describe()               # some basic starts about or columns
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# 4.size

# %%
data.size                     #show no. of total values(elements) in the dataset
# Out:
# 105684

# %% [markdown]
# 5.columns

# %%
data.columns                 # show each column Name
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 6.dtypes

# %%
data.dtypes                 #show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# 7.info()

# %%
# Get summary of dataset:-
data.info()                     # show indexes, columns, data-types of each column, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# duplicate()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data[data.duplicated()]                #check row wise and detect the duplicate rows
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# isnull()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.isnull()                # show where Null value is Present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()                       #show the count of Null Values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# seaborn(heat-map)

# %%
import seaborn as sns                          # import Seaborn Library
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(subset= ['duration'], inplace=True)

#Checking the data shape
print(f'This dataset contains {df.shape[0]} rows and {df.shape[1]} columns now')
# Out:
# This dataset contains 5697 rows and 12 columns now

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8804 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8804 non-null   object
#  1   type          8804 non-null   object
#  2   title         8804 non-null   object
#  3   director      6170 non-null   object
#  4   cast          7979 non-null   object
#  5   country       7973 non-null   object
#  6   date_added    8794 non-null   object
#  7   release_year  8804 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8804 non-null   object
#  11  description   8804 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.2+ KB

# %%
data.dropna(subset= ["director", 'cast'], inplace=True)
data.shape
# Out:
# (5697, 12)

# %%
data["country"].fillna(df["country"].mode()[0], inplace=True)
data["rating"].fillna(df["rating"].mode()[0], inplace=True)
data.shape
# Out:
# (5697, 12)

# %%
#Checking the data shape
print(f'This dataset contains {data.shape[0]} rows and {data.shape[1]} columns now')
# Out:
# This dataset contains 5697 rows and 12 columns now

# %%
#Checking the porcentage of null values at hits point
data.isnull().sum()/len(df)*100
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        0.0
# cast            0.0
# country         0.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# description     0.0
# dtype: float64

# %%
#Counting the amount of movies and tv shows
data["type"].value_counts()
# Out:
# type
# Movie      5519
# TV Show     178
# Name: count, dtype: int64

# %%
# Distribution of content ratings on Netflix
content_type = data.groupby(['type']).size().reset_index(name='counts')
content_type
# Ploting Distribution of content ratings on Netflix
fig = px.pie(content_type, names = 'type',values = 'counts',color_discrete_sequence =  px.colors.sequential.Agsunset,
             title = 'Distribution of Content type on Netflix',height =  500 , width = 700)
fig.show()
# Out:
# <div>                            <div id="221b8c33-e108-41f6-a355-adac916c9ba6" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("221b8c33-e108-41f6-a355-adac916c9ba6")) {                    Plotly.newPlot(                        "221b8c33-e108-41f6-a355-adac916c9ba6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"type=%{label}<br>counts=%{value}<extra></extra>","labels":["Movie","TV Show"],"legendgroup":"","name":"","showlegend":true,"values":[5519,178],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#
# ...

# %% [markdown]
# Which country produces the most content on Netflix?

# %%
grouped_data = data.groupby(['type', 'country']).size().reset_index(name='count')
grouped_data
# Out:
#         type                                            country  count
# 0      Movie                                  , France, Algeria      1
# 1      Movie                                          Argentina     34
# 2      Movie  Argentina, Brazil, France, Poland, Germany, De...      1
# 3      Movie                                   Argentina, Chile      2
# 4      Movie                             Argentina, Chile, Peru      1
# ..       ...                                                ...    ...
# 632  TV Show  United Kingdom, United States, Spain, Germany,...      1
# 633  TV Show                                      United States     58
# 634  TV Show                              United States, Canada      2
# 635  TV Show                             United States, Ireland      1
# 636  TV Show         United States, Israel, Italy, South Africa      1
#
# [637 rows x 3 columns]

# %%
grouped_data = data.groupby(['type', 'country']).size().reset_index(name='count')
grouped_data = grouped_data.sort_values(by="count", ascending=False)
grouped_data = grouped_data.head(10)
fig = px.bar(grouped_data, x='country', y='count', color='country',
             title="Highest Countries for Movies&TV Show",
             labels={'country': "Country", 'count': "Count"},
             color_discrete_map={'United States': 'blue', 'India': 'green'})
fig.update_layout(
     plot_bgcolor='rgba(0,0,0,0)', 
     paper_bgcolor='white',         
     font=dict(color='black')       
 )
fig.show()
# Out:
# <div>                            <div id="b9b5bd94-a09e-44ef-ab1b-26805f215e3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9b5bd94-a09e-44ef-ab1b-26805f215e3f")) {                    Plotly.newPlot(                        "b9b5bd94-a09e-44ef-ab1b-26805f215e3f",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"blue","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[2152],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"India","marker":{"col
# ...

# %% [markdown]
# Q.1.For'House of Cards',what is the show id and who is the Director of this show ?

# %% [markdown]
# isin()

# %%
data[data['title'].isin(['House of Cards'])]        #show all records of a particular item in any column
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# str.contains()

# %%
data[data['title'].str.contains('House of Cards')]  # show all records of a particular string in any column
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Q.2.In which year highest number of the TV Shows & Movies were released ? show with Bar Garph.

# %% [markdown]
# dtypes

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['date_added']
# Out:
# 2       September 24, 2021
# 5       September 24, 2021
# 6       September 24, 2021
# 7       September 24, 2021
# 8       September 24, 2021
#                ...
# 8801         March 9, 2016
# 8802     November 20, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 5697, dtype: object

# %% [markdown]
# to_datetime

# %%
#data['date_added'] = data['date_added'].str.strip()  # Remove leading/trailing whitespace
data['date_added'] = pd.to_datetime(data['date_added'], format="%B %d, %Y", errors='coerce')  # Convert to datetime

# %%
data.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %% [markdown]
# dt.year.value_count()

# %%
data['date_added'].dt.year.value_counts()     #counts the occurance of all individual years in Date column.
# Out:
# date_added
# 2019    1323
# 2020    1248
# 2018    1125
# 2021     962
# 2017     743
# 2016     204
# 2015      51
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: count, dtype: int64

# %% [markdown]
# Bar Garph

# %%
data['date_added'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='date_added'>

# %% [markdown]
# Q.3.How many movies & TV Shows are in the dataset ? Show with Bar Graph.

# %% [markdown]
# groupby()

# %%
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 2  To protect his family from a powerful drug lor...
# 5  The arrival of a charismatic young priest brin...

# %%
data.groupby('type').type.count()        #group all unique items of a column and show their count
# Out:
# type
# Movie      5519
# TV Show     178
# Name: type, dtype: int64

# %% [markdown]
# countplot()

# %%
sns.countplot(x='type', data=data)      # show the count of all unique Values of any column in the form of bar garph
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# Q.4. show all the Movies that were released in year 2021

# %% [markdown]
# Creatting a new a column

# %%
#data.head()
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 2  To protect his family from a powerful drug lor...
# 5  The arrival of a charismatic young priest brin...

# %%
# data['year'] = data['date_added'].dt.year        #creat new year column; it will consider only year
data['year'] = data['date_added'].dt.year

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %% [markdown]
# Flitering

# %%
# data[(data['type']=='Movie') & (data['year']==2021
data[(data['type']=='Movie') & (data['year']==2021)]
# Out:
#      show_id   type                                           title  \
# 6         s7  Movie                My Little Pony: A New Generation
# 7         s8  Movie                                         Sankofa
# 9        s10  Movie                                    The Starling
# 12       s13  Movie                                    Je Suis Karl
# 13       s14  Movie                Confessions of an Invisible Girl
# ...      ...    ...                                             ...
# 8187   s8188  Movie                          The American President
# 8272   s8273  Movie                                    The Departed
# 8320   s8321  Movie                 The Girl with the Dragon Tattoo
# 8434   s8435  Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462  Movie                               The Polar Express
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# ...

# %% [markdown]
# Q.5. Show only the Titles of all TV shows that were released in India only.

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
# data[(data['type']== 'TVshow') & (data['country'] == 'India')] ['title']
data[(data['type'] == 'TV Show') & (data['country'] == 'India')] ['title']
# Out:
# 297                                  Navarasa
# 1293                            Pitta Kathalu
# 1520                          Paava Kadhaigal
# 3036             Jamtara - Sabka Number Ayega
# 4685                                    GHOUL
# 6024                                7 (Seven)
# 8172    Th Eena Meena Deeka Chase Comedy Show
# Name: title, dtype: object

# %% [markdown]
# Q.6. Show Top 10 Directors, who gave the higest number of TV Shows & Movies to Netflix ?

# %% [markdown]
# value_counts()

# %%
#data['director'].value_counts().head(10)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# Q.7.Show all the Records,where "title is Movie and listed_in is Comedies" or "country is United States".

# %% [markdown]
# Flitering(And, Or Operators)

# %%
# data[(data['type']=='Movies') & (data['Type']=='Comedies')]
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
data[ (data['type']=='Movie') & (data['listed_in']=='Comedies') ]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
data[ (data['type']=='Movie') & (data['listed_in']=='Comedies')  | (data['country']=='united States')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %% [markdown]
# Q.8.In how many Movies/shows,Tom Cruise was Cast ?

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %% [markdown]
# filtering

# %%
# data[data['cast']=='Tom cruise']
data[data['cast']=='Tom cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year]
# Index: []

# %% [markdown]
# str.contains()

# %%
# data[data['cast'].str.contains('Tom cruise')]
data[data['cast'].str.contains('Tom cruise')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year]
# Index: []

# %% [markdown]
# Creating new data-frame

# %%
# data_new = data.dropna()
data_new = data.dropna()         # It drop the rows that contains all or any missing Values.

# %%
# data_new.head(2
data_new.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
# data_new[data_new['cast'].str.contains('Tom Cruise')]
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 341  2021-08-01          1999      R  189 min  Dramas, Independent Movies
# 1254 2021-03-01          1988      R  134 min      Classic Movies, Dramas
#
#                                             description  year
# 341   Through chance, history and divine interventio...  2021
# 1254  Motivated by money, a selfish workaholic seeki...  2021

# %% [markdown]
# Q.9.What are the different ratings defined by Netflix ?

# %% [markdown]
# nunique()

# %%
# data .rating.nunique()
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
data .rating.nunique()
# Out:
# 14

# %%
# data.rating.unique()
data.rating.unique()
# Out:
# array(['TV-MA', 'PG', 'TV-14', 'PG-13', 'TV-PG', 'TV-Y', 'R', 'TV-G',
#        'TV-Y7', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Number of Movies\TV Shows Per rating
data['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# data['rating'].value_counts().plot(kind='bar')
data['rating'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='rating'>

# %%
#Ratings
ratings = data.groupby(['rating']).size().reset_index(name='counts')
ratings
# Ploting Distribution of content ratings on Netflix
fig = px.pie(ratings, names = 'rating',values = 'counts',
             title = 'Distribution of ratings on Netflix',height =  600 , width = 600)
fig.show()
# Out:
# <div>                            <div id="dc67391d-4ff3-415d-bd09-f8cbffb518a1" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc67391d-4ff3-415d-bd09-f8cbffb518a1")) {                    Plotly.newPlot(                        "dc67391d-4ff3-415d-bd09-f8cbffb518a1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"rating=%{label}<br>counts=%{value}<extra></extra>","labels":["G","NC-17","NR","PG","PG-13","R","TV-14","TV-G","TV-MA","TV-PG","TV-Y","TV-Y7","TV-Y7-FV","UR"],"legendgroup":"","name":"","showlegend":true,"values":[40,2,58,279,477,789,1329,96,1940,456,102,123,3,3],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks
# ...

# %%
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
# data[(data['type']=='Movie') &(data['rating']=='TV-14)].shape
data[(data['type']=='Movie') &(data['rating']=='TV-14')].shape
# Out:
# (1279, 13)

# %%
# data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')].shape
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')].shape
# Out:
# (10, 13)

# %% [markdown]
# Q.11.How many TV Show got the 'R' rating, after year 2014 ?

# %%
# data[(data['type']=='TV Show') &(data['rating']=='R')]
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
data[(data['type']=='TV Show') &(data['rating']=='R')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast        country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
#
#      date_added  release_year rating  duration listed_in  \
# 3893 2019-04-25          2015      R  1 Season  TV Shows
#
#                                             description  year
# 3893  Trapped at a stagecoach stop as a storm rages ...  2019

# %%
data[(data['type']=='TV Show') &(data['rating']=='R') & (data['release_year']> 2014)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast        country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
#
#      date_added  release_year rating  duration listed_in  \
# 3893 2019-04-25          2015      R  1 Season  TV Shows
#
#                                             description  year
# 3893  Trapped at a stagecoach stop as a storm rages ...  2019

# %% [markdown]
# Q.12.what is the maximum dration of Movies/Show on Netflix ?

# %%
#data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
# data['duration'].unique()
data['duration'].unique()
# Out:
# array(['1 Season', '91 min', '125 min', '9 Seasons', '104 min', '127 min',
#        '94 min', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '110 min', '105 min', '96 min',
#        '124 min', '116 min', '98 min', '115 min', '122 min', '99 min',
#        '88 min', '100 min', '102 min', '93 min', '95 min', '85 min',
#        '83 min', '113 min', '13 min', '182 min', '48 min', '145 min',
#        '87 min', '90 min', '117 min', '128 min', '119 min', '143 min',
#        '114 min', '118 min', '108 min', '63 min', '121 min', '142 min',
#        '154 min', '120 min', '82 min', '109 min', '101 min', '86 min',
#        '229 min', '76 min', '89 min', '156 min', '112 min', '107 min',
#        '129 min', '92 min', '135 min', '136 min', '165 min', '150 min',
#        '133 min', '84 min', '140 min', '2 Seasons', '64 min', '59 min',
#        '139 min', '148 min', '189 min', '141 min', '130 min', '138 min',
# ...

# %%
# data.duration.dtypes
data.duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# str.split()

# %%
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year
# 2  To protect his family from a powerful drug lor...  2021
# 5  The arrival of a charismatic young priest brin...  2021

# %%
# data[['Minutes','Unit']] = data['duration'].str.split(' ',expand=True)
data[['Minutes','Unit']] = data['duration'].str.split(' ',expand=True)

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year Minutes    Unit
# 2  To protect his family from a powerful drug lor...  2021       1  Season
# 5  The arrival of a charismatic young priest brin...  2021       1  Season

# %% [markdown]
# max()

# %%
# data.Minutes.max()
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# Q.13.Which individual country has the Highest No. of TV Shows ?

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year Minutes    Unit
# 2  To protect his family from a powerful drug lor...  2021       1  Season
# 5  The arrival of a charismatic young priest brin...  2021       1  Season

# %%
# data_tvshow = data[data['type'] == 'TV Show']
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year Minutes    Unit
# 2  To protect his family from a powerful drug lor...  2021       1  Season
# 5  The arrival of a charismatic young priest brin...  2021       1  Season

# %%
# data_tvshow.country.value_counts()
data_tvshow.country.value_counts()
# Out:
# country
# United States                                                    58
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# India                                                             7
# Taiwan                                                            7
# France                                                            5
# Turkey                                                            5
# Thailand                                                          5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# United States, Canada                                             2
# ...

# %%
# data_tvshow.country.value_counts().head(1)
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    58
# Name: count, dtype: int64

# %% [markdown]
# Q.14. sort the dataset by Year ?

# %%
# data.head(2)
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year Minutes    Unit
# 2  To protect his family from a powerful drug lor...  2021       1  Season
# 5  The arrival of a charismatic young priest brin...  2021       1  Season

# %%
# data.sort_values(by='release_year').head(5)
data.sort_values(by='release_year').head(5)
# Out:
#      show_id   type                    title  \
# 8205   s8206  Movie     The Battle of Midway
# 8640   s8641  Movie         Tunisian Victory
# 7219   s7220  Movie  Know Your Enemy - Japan
# 7294   s7295  Movie       Let There Be Light
# 8587   s8588  Movie              Thunderbolt
#
#                                                director  \
# 8205                                          John Ford
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# 7219                           Frank Capra, Joris Ivens
# 7294                                        John Huston
# 8587                        William Wyler, John Sturges
#
#                               cast                        country date_added  \
# 8205     Henry Fonda, Jane Darwell                  United States 2017-03-31
# 8640              Burgess Meredith  United States, United Kingdom 2017-03-31
# 7219   Walter Huston, Dana Andrews                  United States 2017-03-31
# ...

# %%
# data.sort_values(by='release_year', ascending=False).head(2)
data.sort_values(by='release_year', ascending=False).head(2)
# Out:
#     show_id     type                    title         director  \
# 2        s3  TV Show                Ganglands  Julien Leclercq
# 766    s767    Movie  Alan Saldaña: Locked Up        Alex Díaz
#
#                                                   cast        country  \
# 2    Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 766                                       Alan Saldaña         Mexico
#
#     date_added  release_year rating  duration  \
# 2   2021-09-24          2021  TV-MA  1 Season
# 766 2021-06-03          2021  TV-MA    49 min
#
#                                              listed_in  \
# 2    Crime TV Shows, International TV Shows, TV Act...
# 766                                    Stand-Up Comedy
#
#                                            description  year Minutes    Unit
# 2    To protect his family from a powerful drug lor...  2021       1  Season
# 766  Mexican comedian Alan Saldaña is back, poking ...  2021      49     min

# %% [markdown]
# Q.14.type is 'Movies' and listed_in 'Dramas'

# %% [markdown]
# or

# %% [markdown]
# type is 'TV Show' and listed_in "kids' TV"

# %%
# data[(data['type']=='Movie') & (data['listrd_in']=='Dramas')].head(2)
data[(data['type']=='Movie') & (data['listed_in']=='Dramas')]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
data.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  United States
#
#   date_added  release_year rating  duration  \
# 2 2021-09-24          2021  TV-MA  1 Season
# 5 2021-09-24          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year Minutes    Unit
# 2  To protect his family from a powerful drug lor...  2021       1  Season
# 5  The arrival of a charismatic young priest brin...  2021       1  Season

# %%
# data[(data['type']=='TV Show') & (data['listed_in']=="kids' TV")].head(2)
data[(data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id     type                    title director  \
# 34       s35  TV Show  Tayo and Little Wizards      NaN
# 39       s40  TV Show             Chhota Bheem      NaN
# 65       s66  TV Show             Numberblocks      NaN
# 89       s90  TV Show              Mighty Raju      NaN
# 100     s101  TV Show  Tobot Galaxy Detectives      NaN
# ...      ...      ...                      ...      ...
# 8669   s8670  TV Show            V.R. Troopers      NaN
# 8679   s8680  TV Show       ViR: The Robot Boy      NaN
# 8783   s8784  TV Show                     Yoko      NaN
# 8785   s8786  TV Show                      YOM      NaN
# 8797   s8798  TV Show                Zak Storm      NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...
# 89    Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...
# ...

# %%
# data[(data['type']=='Movie') & (data['listed_in']=='Dramas')] | (data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
data[(data['type']=='Movie') & (data['listed_in']=='Dramas') | (data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %% [markdown]
# Who are the top 10 directors in Netflix's dataset?

# %%
grouped_data = data.groupby(['director']).size().reset_index(name='count')
grouped_data.head(10)
# Out:
#                      director  count
# 0                 A. L. Vijay      2
# 1                A. Raajdheep      1
# 2                   A. Salaam      1
# 3             A.R. Murugadoss      2
# 4             Aadish Keluskar      1
# 5                Aamir Bashir      1
# 6                  Aamir Khan      1
# 7                  Aanand Rai      1
# 8                 Aaron Burns      1
# 9  Aaron Hann, Mario Miscione      1

# %%
fig = px.bar(grouped_data.head(10), x='director', y='count',
                title="Top 10 directors",
                labels={'director': "Director", 'count': "Count"},
                color_discrete_map={'United States': 'blue', 'India': 'green'})
fig.update_layout(
        plot_bgcolor='rgba(0,0,0,0)', 
        paper_bgcolor='black',         
        font=dict(color='white')       
    )
fig.show()
# Out:
# <div>                            <div id="bf162877-4d69-4f63-8ac9-d43f1bba00bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf162877-4d69-4f63-8ac9-d43f1bba00bc")) {                    Plotly.newPlot(                        "bf162877-4d69-4f63-8ac9-d43f1bba00bc",                        [{"alignmentgroup":"True","hovertemplate":"Director=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["A. L. Vijay","A. Raajdheep","A. Salaam","A.R. Murugadoss","Aadish Keluskar","Aamir Bashir","Aamir Khan","Aanand Rai","Aaron Burns","Aaron Hann, Mario Miscione"],"xaxis":"x","y":[2,1,1,2,1,1,1,1,1,1],"yaxis":"y","type":"b
# ...

# %% [markdown]
#  SUMMARY

# %% [markdown]
# The Netflix dataset has 8807 entries: 69.7% movies and 30.3% TV shows. The peak release year is 2018. Top countries are the USA, India, and the UK. Popular ratings are TV-MA and TV-14, with common genres being dramas, comedies, and documentaries, showcasing Netflix's diverse and global content.

# %% [markdown]
# conclusion

# %% [markdown]
# The Netflix dataset reveals a dynamic and expansive content library, with a strong emphasis on movies, particularly in recent years. The diversity in genres, ratings, and international representation highlights Netflix's strategy to cater to a broad, global audience. This rich variety ensures that Netflix remains a leading platform for entertainment, appealing to diverse tastes and preferences worldwide.
